# %% [markdown]
# <a href="https://colab.research.google.com/github/Aysuliu/ai_foundation/blob/main/vector%26matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
student = [18,1,0] # => [age, gender, has_glasses]

age = 18
gender = 1
has_glasses = 0

# %%
new_age = student[0] + 1
print('new_age', new_age)
# Out:
# new_age 19

# %%
print(student[0])
print(student[1])
print(student[2])
# Out:
# 18
# 1
# 0

# %%
updated_student = [data + 10 for data in student]
print(updated_student)
print(student)
# Out:
# [28, 11, 10]
# [18, 1, 0]

# %%
multiplied_student = [data * 2 for data in student]
print(multiplied_student)
# Out:
# [36, 2, 0]

# %%
halved = [data / 2 for data in student]
print(student)
print(halved)
# Out:
# [18, 1, 0]
# [9.0, 0.5, 0.0]

# %%
minus = [data - 3 for data in student]
print(student)
print(minus)
# Out:
# [18, 1, 0]
# [15, -2, -3]
